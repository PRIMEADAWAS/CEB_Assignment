# %% [markdown]
# # RADI605_A3_PasitSupholkhan (Assignment: Random Survival Forests)

# %% [markdown]
# # Assignment: Random Survival Forest (20 points)
# due: Feb 14, 2023

# %%
# !pip install scikit-survival

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print('Pandas version :',pd.__version__)
print('Numpy version :',np.__version__)
# Out:
# Pandas version : 1.4.4
# Numpy version : 1.23.3

# %% [markdown]
# ## Please use a Worcester Heart Attack dataset (whas500)

# %%
from sksurv.datasets import load_whas500
X, y = load_whas500()
X
# Out:
#     afb   age av3       bmi chf cvd  diasbp gender     hr   los miord mitype  \
# 0     1  83.0   0  25.54051   0   1    78.0      0   89.0   5.0     1      0
# 1     0  49.0   0  24.02398   0   1    60.0      0   84.0   5.0     0      1
# 2     0  70.0   0  22.14290   0   0    88.0      1   83.0   5.0     0      1
# 3     0  70.0   0  26.63187   1   1    76.0      0   65.0  10.0     0      1
# 4     0  70.0   0  24.41255   0   1    85.0      0   63.0   6.0     0      1
# ..   ..   ...  ..       ...  ..  ..     ...    ...    ...   ...   ...    ...
# 495   1  76.0   0  27.96454   0   1    88.0      1   68.0   1.0     0      1
# 496   0  76.0   0  24.26862   0   1    96.0      1   88.0   3.0     0      0
# 497   1  57.0   0  42.13576   0   1    74.0      1  123.0   3.0     0      0
# 498   0  67.0   0  27.40905   0   1    62.0      0   59.0   1.0     0      1
# 499   0  98.0   0  19.48575   0   1   100.0      0   99.0   3.0     0      1
#
#     sho  sysbp
# 0     0  152.0
# ...

# %%
y
# Out:
# array([(False, 2.178e+03), (False, 2.172e+03), (False, 2.190e+03),
#        ( True, 2.970e+02), (False, 2.131e+03), ( True, 1.000e+00),
#        (False, 2.122e+03), ( True, 1.496e+03), ( True, 9.200e+02),
#        (False, 2.175e+03), (False, 2.173e+03), ( True, 1.671e+03),
#        (False, 2.192e+03), ( True, 8.650e+02), (False, 2.166e+03),
#        (False, 2.168e+03), ( True, 9.050e+02), ( True, 2.353e+03),
#        (False, 2.146e+03), ( True, 6.100e+01), ( True, 2.358e+03),
#        (False, 2.114e+03), (False, 2.132e+03), (False, 2.139e+03),
#        (False, 2.048e+03), (False, 2.152e+03), ( True, 6.000e+00),
#        (False, 2.156e+03), ( True, 1.180e+02), (False, 2.064e+03),
#        ( True, 8.490e+02), ( True, 7.140e+02), (False, 2.057e+03),
#        ( True, 2.000e+00), ( True, 7.000e+00), (False, 2.151e+03),
#        ( True, 6.000e+00), ( True, 4.220e+02), ( True, 3.540e+02),
#        (False, 2.065e+03), (False, 2.048e+03), ( True, 1.065e+03),
# ...

# %% [markdown]
# ## Split whas500 into training and testing set (70:30)

# %%
#Spliting data 30% as test / 70% as training
from sklearn.model_selection import train_test_split
seed = 6536115
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state=seed)
print(X_train.shape,
X_test.shape,
y_train.shape,
y_test.shape)
# Out:
# (350, 14) (150, 14) (350,) (150,)

# %% [markdown]
# ## Build a random survival forest model by using training set

# %%
#Training
from sksurv.ensemble import RandomSurvivalForest
rsf = RandomSurvivalForest(n_estimators=1000,
min_samples_split=10,
min_samples_leaf=15,
max_features="sqrt",
n_jobs=-1,
random_state=seed)
rsf.fit(X_train,y_train)
# Out:
# RandomSurvivalForest(min_samples_leaf=15, min_samples_split=10,
#                      n_estimators=1000, n_jobs=-1, random_state=6536115)

# %% [markdown]
# ## Evaluate your model performance by using testing set

# %%
#check how well the model performs by evaluating it on the test data.
rsf.score(X_test, y_test)
# Out:
# 0.7905180248409572

# %%
X_test
# Out:
#     afb   age av3       bmi chf cvd  diasbp gender     hr  los miord mitype  \
# 199   0  45.0   0  37.06646   0   1    70.0      0  110.0  3.0     0      1
# 43    0  62.0   0  33.33395   0   1    50.0      0   50.0  5.0     0      0
# 289   0  63.0   0  28.12934   0   1    92.0      0   54.0  9.0     0      1
# 212   0  47.0   0  38.78883   0   0    99.0      0  101.0  2.0     0      1
# 61    0  63.0   0  21.25718   1   1    70.0      1   76.0  4.0     0      1
# ..   ..   ...  ..       ...  ..  ..     ...    ...    ...  ...   ...    ...
# 31    0  61.0   0  25.46070   1   0    80.0      1  111.0  5.0     0      0
# 89    0  82.0   0  17.89146   0   1    70.0      1   83.0  7.0     0      0
# 170   1  65.0   0  26.95468   0   0    90.0      0   42.0  7.0     0      1
# 144   1  50.0   0  23.88798   0   1    94.0      1   72.0  4.0     0      1
# 220   0  84.0   0  27.97729   0   1    74.0      0   71.0  3.0     1      0
#
#     sho  sysbp
# 199   0  130.0
# 43    0   80.0
# ...

# %%
#Predicting
#Let’s first select a couple of patients from the test data according to age and the number of bmi
X_test_sorted = X_test.sort_values(by=["age","bmi"])
X_test_sel = pd.concat((X_test_sorted.head(3), X_test_sorted.tail(3)))
X_test_sel
# Out:
#     afb    age av3       bmi chf cvd  diasbp gender    hr  los miord mitype  \
# 110   0   30.0   0  29.85998   0   0   102.0      0  90.0  2.0     0      1
# 437   0   32.0   0  30.55383   0   1    83.0      0  90.0  2.0     0      0
# 302   0   36.0   0  31.64232   0   0    20.0      0  98.0  1.0     1      0
# 354   0   95.0   0  27.98863   1   1    62.0      0  80.0  1.0     1      1
# 499   0   98.0   0  19.48575   0   1   100.0      0  99.0  3.0     0      1
# 250   0  102.0   0  22.27393   1   0    60.0      0  89.0  3.0     0      0
#
#     sho  sysbp
# 110   0  175.0
# 437   0  132.0
# 302   0  132.0
# 354   0  111.0
# 499   0  160.0
# 250   0  118.0

# %%
#The predicted risk scores indicate that risk for the last three patients is quite a bit higher than that of the first three patients.
pd.Series(rsf.predict(X_test_sel))
# Out:
# 0     16.871913
# 1     21.870678
# 2     31.664620
# 3     99.903368
# 4     77.675430
# 5    125.588643
# dtype: float64

# %% [markdown]
# ## Plot survival curve

# %%
#Plot survivalcurve
surv = rsf.predict_survival_function(X_test_sel, return_array=True)
for i,s in enumerate(surv):
    plt.step(rsf.event_times_,s, where="post", label=str(i))
plt.ylabel("Survival probability")
plt.xlabel("Time in days")
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Plot the predicted cumulative hazard function

# %%
#plot thepredictedcumulativehazardfunction.
surv = rsf.predict_cumulative_hazard_function(X_test_sel, return_array=True)
for i,s in enumerate(surv):
    plt.step(rsf.event_times_,s, where="post", label=str(i))
plt.ylabel("Cumulative hazard")
plt.xlabel("Time in days")
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Summarize the results

# %% [markdown]
# the result show that if patient has an old age or high bmi will take more risk then the survival propability will decrease. However the cumulative hazard will increase instead. Especially if they have and old age with high BMI will get the highest risk and cumulative hazard. but get lowest survival propability.
